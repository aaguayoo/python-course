# %% [markdown]
# # Validador de contraseñas

# %% [markdown]
# Cada uno de los siguientes puntos debería considerarse como un método de una clase
# - Mínimo un dígito
# - Mínimo una mayúscula
# - Mínimo un caracter especial
# - Mínimo 8 caracteres
# - Máximo 16 caracteres

# %%
class PasswordValidator:
    
    def __init__(self):
        pass
    
    def minimum_digit_validation(self)-> bool:
        return ...
    
    def minimum_upper_case(self)-> bool:
        return ...
    
    def minimum_special_char(self) -> bool:
        return ...
    
    def validate_password(self, password: str) -> bool:
        self.password = password
        
        if self.minimum_upper_case() and self.minimum_digit_validation and self.minimum_special_char():
            return True
        else:
            return False

# %%
from pydantic import validator

# Esquema
class UserAcount:
    
    user: str
    user_id: str
    password: str
    acount_number: int
    
    @validator(password)
    def password_validator(cls):
        validator = PasswordValidor()
        assert validator.valide_password(cls.password)

# %%
UserAcount(
    user="Astrid",
    user_id="1234",
    password="password"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 UserAcount(
#       2     user="Astrid",
#       3     user_id="1234",
#       4     password="password"
#       5 )
#
# NameError: name 'UserAcount' is not defined
