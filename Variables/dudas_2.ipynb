# %% [markdown]
# Ejercicios
#
# 1. Escribe un programa que lea repetidamente números hasta que el usuario introduzca “fin”. Una vez se haya introducido “fin”, muestra por pantalla el total, la cantidad de números y la media de esos números. Si el usuario introduce cualquier otra cosa que no sea un número, detecta su fallo usando try y except, muestra un mensaje de error y pasa al número siguiente.
#
# ![image.png](attachment:40e3cf33-7485-4537-b1cc-93d3b355d710.png)

# %%
number = input("Introduce un número: ")

numbers_list = []

while number.lower() != "fin":
    try:
        number = float(number)
        numbers_list.append(number)
        number = input("Introduce un número: ")
    except Exception:
        print("Error")
        number = input("Introduce un número: ")
        continue

if numbers_list:
    total = sum(numbers_list)
    count = len(numbers_list)
    mean = total/count
    print(total, count, mean)
# Out:
# Introduce un número:  3
# Introduce un número:  fin
# 3.0 1 3.0

# %%
number = input("Introduce un número:")

numbers_list = []

while True:
    try:
        number = float(number)
        numbers_list.append(number)
        number = input("Introduce un número:")
    except Exception:
        if number.lower() == "fin":
            break
            
        print("Error")
        number = input("Introduce un número:")
        continue

if numbers_list:
    total = sum(numbers_list)
    count = len(numbers_list)
    mean = total/count
    print(total, count, mean)
# Out:
# Introduce un número: 3
# Introduce un número: 5
# Introduce un número: Fin
# 8.0 2 4.0
